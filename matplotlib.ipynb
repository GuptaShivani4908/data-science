# %%
# !git init

# !git remote add origin https://github.com/GuptaShivani4908/data-science.git

# !git branch -M main

# !git add .

# !git commit -m "matplotlib start here "

# !git push -u origin main --force
# Out:
# Reinitialized existing Git repository in C:/Users/shiva/data science/.git/
# error: remote origin already exists.
# warning: in the working copy of 'pandas1.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.ipynb_checkpoints/matplotlib-checkpoint.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'matplotlib.ipynb', LF will be replaced by CRLF the next time Git touches it
# [main e50a5e2] matplotlib start here
#  5 files changed, 812 insertions(+), 10 deletions(-)
#  create mode 100644 .ipynb_checkpoints/matplotlib-checkpoint.ipynb
#  create mode 100644 actor - Sheet1_updated.csv
#  create mode 100644 actor - Sheet1_updates.csv
#  create mode 100644 matplotlib.ipynb
# branch 'main' set up to track 'origin/main'.
# To https://github.com/GuptaShivani4908/data-science.git
#    ba85073..e50a5e2  main -> main

# %%
# Plotting Charts using Matplotlib
