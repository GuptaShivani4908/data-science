# %%
# !git init

# !git remote add origin https://github.com/GuptaShivani4908/data-science.git

# !git branch -M main

# !git add .

# !git commit -m "Histograms in Matplotlib"

# !git push -u origin main --force
# Out:
# Reinitialized existing Git repository in C:/Users/shiva/data science/.git/
# error: remote origin already exists.
# warning: in the working copy of 'matplotlib.ipynb', LF will be replaced by CRLF the next time Git touches it
# [main 8a23042] Histograms in Matplotlib
#  1 file changed, 250 insertions(+), 77 deletions(-)
# branch 'main' set up to track 'origin/main'.
# To https://github.com/GuptaShivani4908/data-science.git
#    75877d6..8a23042  main -> main

# %%
# Plotting Charts using Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3],[4,5,6])

# %%
years = [1990, 1992, 1994, 1996, 1998, 2000, 2003, 2005, 2007, 2010]
runs =  [500, 700, 1100, 1500, 1800, 1200, 1700, 1300, 900, 1500]

plt.plot(years, runs)
plt.show()

# %%
plt.plot(years,runs)

# %%
plt.xlabel("years")
# Out:
# Text(0.5, 0, 'years')

# %%
plt.ylabel("runs scored")
# Out:
# Text(0, 0.5, 'runs scored')

# %%
plt.title("sachin tendulkars yearly runs")
# Out:
# Text(0.5, 1.0, 'sachin tendulkars yearly runs')

# %%
plt.show()

# %%
plt.plot(years, runs)
plt.xlabel("Year")
plt.ylabel("Runs Scored")
plt.title("Sachin Tendulkar's Yearly Runs")
plt.show()

# %%
kohli= [0,0,500,800,1100,1300,1500,1800,1900,2100]
sehwag =[0,300,800,1200,1500,1700,1600,1400,1000,0]
plt.plot(years,kohli, label="virat kohli")
plt.plot(years,sehwag,label="virende sehwag")

plt.xlabel("year")
plt.ylabel("runs scored")
plt.title("performance comparison")
plt.legend()
plt.show()

# %%
kohli= [0,0,500,800,1100,1300,1500,1800,1900,2100]
sehwag =[0,300,800,1200,1500,1700,1600,1400,1000,0]
plt.plot(years,kohli)
plt.plot(years,sehwag)

plt.legend(["kholi","sehwag"])

plt.xlabel("year")
plt.ylabel("runs scored")
plt.title("performance comparison")

plt.show()

# %%
plt.plot(years,kohli,'ro--', label="kohli") #r = red color , o =circlevformat
plt.plot(years,sehwag,'g^:',label="sehwag")#g= green , ^= triangle
plt.legend()

# %%
plt.plot(years,kohli,'-g', label="kohli") #r = red color , o =circlevformat
plt.plot(years,sehwag,'b-.',label="sehwag")#g= green , ^= triangle
plt.grid()
plt.tight_layout()
plt.legend()

# %%
# linewidth
plt.tight_layout()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
with plt.xkcd():
    plt.plot(years,kohli,'-g', label="kohli") #r = red color , o =circlevformat
plt.plot(years,sehwag,'b-.',label="sehwag")#g= green , ^= triangle
plt.grid(True)
plt.tight_layout()
plt.legend()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.

# %%
with plt.xkcd():
    plt.plot(years, kohli, label="Kohli")
    plt.plot(years, sehwag, label="Sehwag")
    plt.title("Epic Battle of the Batsmen")
    plt.legend()
    plt.show()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.

# %%
import numpy as np

for i in range(1):
    plt.plot(np.random.rand(100), linewidth=1)

plt.title("Too Much Data Can Be Confusing!")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.plot(years , kohli, label="kohli")
plt.plot(years , Rohit , label="Rohit sharma")
plt.plot(years , Sehwag, label="Sehwag")
plt.show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 plt.plot(years , kohli, label="kohli")
# ----> 2 plt.plot(years , Rohit , label="Rohit sharma")
#       3 plt.plot(years , Sehwag, label="Sehwag")
#       4 plt.show
#
# NameError: name 'Rohit' is not defined

# %%
kohli= [0,0,500,800,1100,1300,1500,1800,1900,2100]
Rohit =[0,100,200,500,1500,1200,2000,500,2200,1000]
Sehwag =[0,300,800,1200,1500,1700,1600,1400,1000,0]
plt.plot(years,kohli)
plt.plot(years,Sehwag)
plt.plot(years,Rohit)

# %%
plt.plot(years,kohli,'-g', label="kohli") #r = red color , o =circlevformat
plt.plot(years,sehwag,'b-.',label="sehwag")#g= green , ^= triangle
plt.grid()
plt.tight_layout()
plt.legend()

# %%
# Bar Charts in Matplotlib

# %%
years =[2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010]
runs =[500,600,500,700,800,900,1200,1500,1800,1900,2010]
plt.bar(years,runs)
plt.xlabel("year")
plt.ylabel("runs scored")
plt.title("sachin tend")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 3
#       1 years =[2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010]
#       2 runs =[500,600,500,700,800,900,1200,1500,1800,1900,2010]
# ----> 3 plt.bar(years,runs)
#       4 plt.xlabel("year")
#       5 plt.ylabel("runs scored")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py:2989, in bar(x, height, width, bottom, align, data, **kwargs)
#    2978 @_copy_docstring_and_deprecators(Axes.bar)
#    2979 def bar(
#    2980     x: float | ArrayLike,
#    (...)
#    2987     **kwargs,
#    2988 ) -> BarContainer:
# -> 2989     return gca().bar(
#    2990         x,
#    2991         height,
#    2992         width=width,
#    2993         bottom=bottom,
#    2994         align=align,
#    2995         **({"data": data} if data is not None else {}),
#    2996         **kwargs,
#    2997     )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_axes.py:2583, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2580     if yerr is not None:
#    2581         yerr = self._convert_dx(yerr, y0, y, self.convert_yunits)
# -> 2583 x, height, width, y, linewidth, hatch = np.broadcast_arrays(
#    2584     # Make args iterable too.
#    2585     np.atleast_1d(x), height, width, y, linewidth, hatch)
#    2587 # Now that units have been converted, set the tick locations.
#    2588 if orientation == 'vertical':
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\_stride_tricks_impl.py:544, in broadcast_arrays(subok, *args)
#     537 # nditer is not used here to avoid the limit of 32 arrays.
#     538 # Otherwise, something like the following one-liner would suffice:
#     539 # return np.nditer(args, flags=['multi_index', 'zerosize_ok'],
#     540 #                  order='C').itviews
#     542 args = [np.array(_m, copy=None, subok=subok) for _m in args]
# --> 544 shape = _broadcast_shape(*args)
#     546 result = [array if array.shape == shape
#     547           else _broadcast_to(array, shape, subok=subok, readonly=False)
#     548                           for array in args]
#     549 return tuple(result)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\_stride_tricks_impl.py:419, in _broadcast_shape(*args)
#     414 """Returns the shape of the arrays that would result from broadcasting the
#     415 supplied arrays against each other.
#     416 """
#     417 # use the old-iterator because np.nditer does not handle size 0 arrays
#     418 # consistently
# --> 419 b = np.broadcast(*args[:32])
#     420 # unfortunately, it cannot handle 32 or more arguments directly
#     421 for pos in range(32, len(args), 31):
#     422     # ironically, np.broadcast does not properly handle np.broadcast
#     423     # objects (it treats them as scalars)
#     424     # use broadcasting to avoid allocating the full array
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape.  Mismatch is between arg 0 with shape (10,) and arg 1 with shape (11,).

# %%
x=np.arange(len(years))
width=0.25

# %%
x

# %%
import numpy as np 
years =[2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010]
kohli= [0,500,800,1100,1300,1500,1800,1900,2100,900]
Rohit =[0,100,200,500,1500,1200,2000,500,2200,1000]
Sehwag =[0,300,800,1200,1500,1700,1600,1400,1000,0]

x = np.arange(len(years))
width=0.25

plt.bar(x - width , kohli, width=width, label="kohli")
plt.bar(x, Rohit, width=width, label="Rohit")
plt.bar(x + width , Sehwag, width=width , label="Sehwag")

plt.xlabel("Year")
plt.ylabel("Runs")
plt.title("Runs Comparison")
plt.xticks(x,years)
plt.legend()
plt.tight.layout()
plt.show()

# %%
years =[2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010]

import numpy as np

sachin = [500, 700, 1100, 1500, 1800, 1200, 1700, 1300, 900, 1500]
sehwag = [0, 200, 900, 1400, 1600, 1800, 1500, 1100, 800, 0]
kohli  = [0, 0, 500, 800, 1100, 1300, 1500, 1800, 1900, 2100]

x = np.arange(len(years))  # index positions
width = 0.25



plt.bar(x - width, sachin, width=width, label="Sachin")
plt.bar(x, sehwag, width=width, label="Sehwag")
plt.bar(x + width, kohli, width=width, label="Kohli")

plt.xlabel("Year")
plt.ylabel("Runs")
plt.title("Run Comparison")
plt.xticks(x, years)  # Show actual year(2003) instead of 0,1,2,...
plt.legend()
plt.tight_layout()
plt.show()

# %%
players =["sachin","sehwag","kohli","yuvraj"]
runs_5yrs=[500+600+700+1100+1500+1800, 0+200+900+1400+1600, 0+0+500+800+1000, 300+600+800+1100+900]
plt.barh(players,runs_5yrs, color="skyblue") #horizontal barh
plt.xlabel("total runs in first 5 years")
plt.title("5 years performence")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

players = ["Sachin", "Sehwag", "Kohli"]
runs = [1500, 1200, 1800]

plt.bar(players, runs, color="lightgreen")

# Add labels on top of bars
for i in range(len(players)):
    plt.text(i, runs[i] + 30, str(runs[i]), ha='center')

plt.ylabel("Runs")
plt.title("Runs Scored by Players")
plt.tight_layout()
plt.show()

# %%
# Create a side-by-side bar chart comparing runs of Sachin, Kohli, and Sehwag over 5 selected years.

# %%
# players=["sachin","koghli","sehwag"]
# runs =[0+300+400+500+800, 0+800+1200+100+20, 1000+0+100+800+2500]
# years=[2000,2001,2002,2003,2004]
# plt.bar(players, years , runs , color="lightpink")
years = [1996, 1998, 2000, 2003, 2005]
sachin = [1500, 1800, 1200, 1700, 1300]
sehwag = [1400, 1600, 1800, 1500, 1100]
kohli = [800, 1100, 1300, 1500, 1800]

# x = np.arange(len(years))
# width=0.25

# plt.bar(x - width, sachin, width=width, label="Sachin", color='royalblue')
# plt.bar(x, sehwag, width=width, label="Sehwag", color='orange')
# plt.bar(x + width, kohli, width=width, label="Kohli", color='forestgreen')


# plt.xlabel("Selected Years")
# plt.ylabel("Runs")
# plt.title("Run Comparison Over 5 Selected Years")
# plt.xticks(x, years)
# # plt.legend()
# plt.tight_layout()
# plt.show()

# %%
years = [1996, 1998, 2000, 2003, 2005]
sachin = [1500, 1800, 1200, 1700, 1300]
sehwag = [1400, 1600, 1800, 1500, 1100]
kohli = [800, 1100, 1300, 1500, 1800]

plt.bar(x, sachin)
plt.bar(x,sehwag)
plt.bar(x, kohli)

# plt.xticks(years)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 6
#       3 sehwag = [1400, 1600, 1800, 1500, 1100]
#       4 kohli = [800, 1100, 1300, 1500, 1800]
# ----> 6 plt.bar(x, sachin)
#       7 plt.bar(x,sehwag)
#       8 plt.bar(x, kohli)
#
# NameError: name 'x' is not defined

# %%
# Pie Charts in Matplotlib

# %%
plt.style.use("ggplot")

# %%
labels=["sachin","sehwag","kohli","yuvraj"]
runs =[18000,8000,12000,3000]

plt.title("career runs")
plt.pie(runs, labels=labels)
plt.show()

# %%
labels=["sachin","sehwag","kohli","yuvraj"]
runs =[18000,8000,12000,3000]

colors=['lightpink','skyblue','lightgreen','#654321']
plt.pie(runs, labels=labels, colors=colors)
plt.show()

# %%
plt.pie(
    runs, 
    labels=labels,
    colors=colors, 
    wedgeprops={'edgecolor':'green', 'linewidth':2,'linestyle':'--', 'fill':False}
)
plt.show()

# %%
plt.pie(
    runs, 
    labels=labels,
    colors=colors, 
    wedgeprops={'edgecolor':'green', 'linewidth':2,'linestyle':'--', 'fill':True}
)
plt.show()

# %%
explode =[0.1,0. ,0 ,0]

plt.pie(runs, labels=labels, colors = colors, explode=explode, shadow=True, startangle=120, autopct='%1.1f%%')
plt.title("exploded")
plt.show()

# %%
# Too many categories
languages = ['Python', 'Java', 'C++', 'JavaScript', 'C#', 'Ruby', 'Go', 'Rust', 'Swift', 'PHP']
usage = [30, 20, 10, 10, 7, 5, 4, 3, 2, 1]

plt.pie(usage, labels=languages, autopct='%1.1f%%', startangle=90)
plt.title("Programming Language Usage (Crowded Example)")
plt.show()

# %%
# Stack Plots in Matplotlib

# %%
activities=['studying','playing','waching tv','sleeping']

# %%
time_spend=[3,2,1,5]
colors=['blue','pink','green','red']
plt.figure(figsize=(6,6))
plt.pie(time_spend, labels=activities,colors=colors,startangle=90,autopct="%1.1f%%")
# plt.title("school goes student")
# plt.axis('equal')
# Out:
# ([<matplotlib.patches.Wedge at 0x195c168c940>,
#   <matplotlib.patches.Wedge at 0x195c168c880>,
#   <matplotlib.patches.Wedge at 0x195c168d570>,
#   <matplotlib.patches.Wedge at 0x195c168dd20>],
#  [Text(-0.8313246038716089, 0.7203467241528296, 'studying'),
#   Text(-0.8313244779221698, -0.7203468695062345, 'playing'),
#   Text(1.311736850028664e-08, -1.0999999999999999, 'waching tv'),
#   Text(1.0888036038816888, 0.15654619821077317, 'sleeping')],
#  [Text(-0.4534497839299684, 0.39291639499245246, '27.3%'),
#   Text(-0.4534497152302744, -0.3929164742761279, '18.2%'),
#   Text(7.1549282728836204e-09, -0.5999999999999999, '9.1%'),
#   Text(0.5938928748445574, 0.08538883538769444, '45.5%')])

# %%
days = [1,2,3,4,5,6,7]
studying =[3,4,3,5,6,3,4]
playing = [2,2,1,1,3,2,1]
watching_tv =[2,1,2,2,1,1,1]
sleeping = [5,5,6,5,1,5,5]

labels =['studying','playing','Watching','sleeping']
colors=['pink','blue','green','red']
plt.figure(figsize=(10,6))
plt.stackplot(days, studying , playing, watching_tv ,sleeping , 
              labels=labels, colors=colors, alpha=0.4)

plt.legend(loc='upper left')
plt.title("data")
plt.xlabel("days")
plt.ylabel("hours")
plt.grid(True)
plt.show()

# %%
# Histograms in Matplotlib

# %%
data = [22,55,66,55,22,88,99,55,44,35,65,75,58,96,2,82
        ,65,55,5,55,66,88,9,92,44,42,5]
bins =[10,20,30,40,50,60]

# %%
plt.hist(data,bins=5, edgecolor="black")
# Out:
# (array([4., 3., 9., 5., 6.]),
#  array([ 2. , 21.4, 40.8, 60.2, 79.6, 99. ]),
#  <BarContainer object of 5 artists>)

# %%
plt.hist(data,bins=bins, edgecolor="black")
plt.axvline(15, color ='red',linestyle='--', linewidth=2, label="Average")
plt.title("data")
plt.xlabel("days")
plt.ylabel("hours")
plt.grid(True , linestyle='--',alpha=0.5)
plt.show()
